# %%
#task-1
insta_followers={
    "akansha_chaudhari":4000000,
    "yogesh rawat":2000000,
    "virat kohli":27000000,
    "cristiano": 650000000,
    "selenagomez": 420000000
}

print(insta_followers)
# Out:
# {'akansha_chaudhari': 4000000, 'yogesh rawat': 2000000, 'virat kohli': 27000000, 'cristiano': 650000000, 'selenagomez': 420000000}

# %%
#task-2

#add influencer
add={"kyliejenner": 390000000}
insta_followers.update(add)

#update follower count
insta_followers.update({"virat kohli":"27000000"})

#delete insta follower
del insta_followers["selenagomez"]
print(insta_followers)
# Out:
# {'akansha_chaudhari': 4000000, 'yogesh rawat': 2000000, 'virat kohli': '27000000', 'cristiano': 650000000, 'kyliejenner': 390000000}

# %%
#task-3
food_prices={
    "pizza":300,
    "burger":150,
    "pasta":170,
    "panner tikka":250,
    "biryani":300
}

for item,price in food_prices.items():
    if price>200:
        print(item,"₹",price)
# Out:
# pizza ₹ 300
# panner tikka ₹ 250
# biryani ₹ 300

# %%
#task-4
flipkart_users={"mahek","bhumi","asmita","rajal","heer"}
myntra_users={"isha","kirti","krina","mahek","heer"}

common_users = flipkart_users.intersection(myntra_users)

print(common_users)
# Out:
# {'heer', 'mahek'}

# %%
#task-5
def get_unique_artists(spotify_playlist1, spotify_playlist2):
    return playlist1.union(playlist2)

playlist1={"arijit singh","karan aujla","shreya ghoshal"}    
playlist2={"arijit singh","Neha Kakkar", "Atif Aslam"}

unique_artist=playlist1.union(playlist2)

print(unique_artist)
# Out:
# {'Neha Kakkar', 'Atif Aslam', 'shreya ghoshal', 'arijit singh', 'karan aujla'}
