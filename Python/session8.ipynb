# %%
#task-1
food_apps=["zomato","swiggy","uber eats","blinkit","domino's"]
for i in food_apps:
    print(i)
# Out:
# zomato
# swiggy
# uber eats
# blinkit
# domino's

# %%
#task-2
steps=[7300,9300,2700,10200,1200,10400]
i=0
while i < len(steps):
    if steps[i] > 10000:
        print("First day of crossing 10000 steps:",i+1)
        break
    i+=1
# Out:
# First day of crossing 10000 steps: 4

# %%
#task-3
teams=["MI","RCB","CSK","RR","Punjab"]
def long_team_names(teams):
    for team in teams:
        if len(team) >= 6:
            print(team)
long_team_names(teams)
# Out:
# Punjab

# %%
#task-4
dur

ation=[290,120,230,200,170]
for position,duration in enumerate(duration, start=1):
    print(f"song {position}:{duration} seconds")
# Out:
# song 1:290 seconds
# song 2:120 seconds
# song 3:230 seconds
# song 4:200 seconds
# song 5:170 seconds

# %%
#task-5
prices=[200,300,500,500,700,300]
total=0
for price in prices:
    if price==0:
        continue
    total+=price
    if total>2000:
        break
print("Final total:₹",total)
# Out:
# Final total:₹ 2200
