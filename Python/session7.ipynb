# %%
#task-1
spotify_listening_time=int(input("Enter your spotify listening time:"))
if spotify_listening_time>120:
    print("You are a true music fan!")
else:
    print("Keep listening")
# Out:
# Enter your spotify listening time: 150
# You are a true music fan!

# %%
#task-2
amount=int(input("enter your zomato order amount:"))
if amount>300:
    print("Eligible for free delivery")
else:
    print("Delivery charges apply")
# Out:
# enter your zomato order amount: 400
# Eligible for free delivery

# %%
#task-3
flipkart_cart_total=int(input("Enter your flipkart cart total:"))
if flipkart_cart_total>2000:
    print("You get a 10% discount")
elif flipkart_cart_total>1000:
    print("You get a 5% discount")
else:
    print("No discount available")
# Out:
# Enter your flipkart cart total: 1500
# You get a 5% discount

# %%
#task-4
points=int(input("Enter IPL teams points:"))
if points>800:
    print("Champion")
else:
    if points>=500:
        print("Top Performer")
    else:
        print("Keep trying")
# Out:
# Enter IPL teams points: 500
# Top Performer
