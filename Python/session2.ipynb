# %%
#task-1
item_price=250
delivery_fee=30
coupon_discount=20

print("Item price:",item_price)
print("Delivery fee:",delivery_fee)
print("Coupon discount:",coupon_discount)
# Out:
# Item price: 250
# Delivery fee: 30
# Coupon discount: 20

# %%
#task-2
price=5000
if(price>1000):
    print("Eligible for free delivery")
else:
    print("Delivery charges apply")
# Out:
# Eligible for free delivery

# %%
#task-3
#single-line comment
"""
This program checks whether a Flipkart product qualifies for free delivery.
If the price is greater than 1000, it prints a free delivery message.
Otherwise, it prints that delivery charges will apply.
"""
print("hello")
# Out:
# hello

# %%
#task-4
team_name="GT"
run_scored=78
overs_played=20

print("Team name:",team_name)
print("Run scored:",run_scored)
print("Overs played:",overs_played)
# Out:
# Team name: GT
# Run scored: 78
# Overs played: 20
