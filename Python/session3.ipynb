# %%
#task-1
age=20
height=60.3
name="mahek"
spotify_account=True
print("age:",age)
print("height:",height)
print("name:",name)
print("spotify account:",spotify_account)
print("Data type age:",type(age))
print("Data type height:",type(height))
print("Data type name:",type(name))
print("Data type spotify_account:",type(spotify_account))
# Out:
# age: 20
# height: 60.3
# name: mahek
# spotify account: True
# Data type age: <class 'int'>
# Data type height: <class 'float'>
# Data type name: <class 'str'>
# Data type spotify_account: <class 'bool'>

# %%
#task-2
price= ['199.99', '49', '350.75']    
def total_cart(price):
    total=0
    for i in price:
        total+=float(i)
    return total
total=total_cart(price)
print("total amount:",total)
# Out:
# total amount: 599.74

# %%
#task-3
score=int(input("enter your cricket score:"))
if score>=50:
    print("Half-century")
else:
    print("keep going")
# Out:
# enter your cricket score: 29
# keep going

# %%
#task-4
is_premium="True"
is_premium_bool=is_premium=='True'
print(is_premium_bool)
print(type(is_premium_bool))
# Out:
# True
# <class 'bool'>
