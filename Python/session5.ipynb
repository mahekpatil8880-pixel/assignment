# %%
#task-1
playlist_ids=[1,2,3,4,5]
print(playlist_ids )
# Out:
# [1, 2, 3, 4, 5]

# %%
#task-2
playlist_ids.append(6)
print(playlist_ids)

x=[7,8]
playlist_ids.extend(x)
print(playlist_ids)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
#task-3
playlist_ids.pop()
print(playlist_ids)
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
#task-4(error-messasge)
insta_filters = ("Vintage", "Glow", "Black & White", "Retro")
print(insta_filters)
insta_filters[0] = "Nature"
# Out:
# ('Vintage', 'Glow', 'Black & White', 'Retro')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 insta_filters = ("Vintage", "Glow", "Black & White", "Retro")
#       2 print(insta_filters)
# ----> 3 insta_filters[0] = "Nature"
#
# TypeError: 'tuple' object does not support item assignment

# %%
#task-5
zomato_orders=["pizza","burger","pasta","biryani"]
ipl_teams=("RCB","MI","GT","CSK")

#Use a list for Zomato orders because new orders can be added or existing orders can be removed.
# Use a tuple for IPL teams because the fixed team names should not be changed frequently.

print("Zomato order:",zomato_orders)
print("IPL teams:",ipl_teams)
# Out:
# Zomato order: ['pizza', 'burger', 'pasta', 'biryani']
# IPL teams: ('RCB', 'MI', 'GT', 'CSK')
