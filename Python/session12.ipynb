# %%
#task-1
songs=['Shape Of You', 'Blinding Lights', 'Levitating', 'Senorita']
lower_case=map(lambda songs: songs.lower(),songs)
print(list(lower_case))
# Out:
# ['shape of you', 'blinding lights', 'levitating', 'senorita']

# %%
#task-2
zomato_rating= [4.2, 3.8, 4.5, 2.9, 3.5]
rating=filter(lambda zomato_rating: zomato_rating>4.0, zomato_rating)
print(list(rating))
# Out:
# [4.2, 4.5]

# %%
#task-3
from functools import reduce
flipkart_shopping_cart=[499, 1299, 299, 799]
total=reduce(lambda a,b: a+b, flipkart_shopping_cart)
print(total)
# Out:
# 2896

# %%
#task-4
follower_counts=[950, 1500, 25000, 1200000]
def followers(num):
    if num>1000000:
        return str(num/1000000) + "M"
    elif num>1000:
        return str(num/1000) + "K"
    else:
        return str(num)
format=map(followers, follower_counts)sss
print(list(format))
# Out:
# ['950', '1.5K', '25.0K', '1.2M']

# %%
#task-5
scores=[101, 98, 120, 77, 88]
even_score=filter(lambda x: x%2==0 , scores)
print(list(even_score))
# Out:
# [98, 120, 88]
