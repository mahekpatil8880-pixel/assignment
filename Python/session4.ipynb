# %%
#task-1
text="Flipkart-Sale2024"
print("lower text:",text.lower())
print("Replace:",text.replace("-"," "))
# Out:
# lower text: flipkart-sale2024
# Replace: Flipkart Sale2024

# %%
#task-2
text1="OnePlus Nord-CE 3"
print("strip:",text1.strip())
print("upper text:",text1.upper())
print("Repalce:",text1.replace("-",":"))
# Out:
# strip: OnePlus Nord-CE 3
# upper text: ONEPLUS NORD-CE 3
# Repalce: OnePlus Nord:CE 3

# %%
#task-3
code="ZOMATO-FOOD-2024"
def split_product_code(product_code):
    return product_code.split('-')
result=split_product_code(code)        
print(result)
# Out:
# ['ZOMATO', 'FOOD', '2024']

# %%
#task-4
text="Spotify_Premium_Offer"
print("character:",text[8:15])
# Out:
# character: Premium

# %%
#task-5
product = 'Myntra Shirt'
price = 799.5
print(f"Deal: {product} is available at ₹{price} only!")
# Out:
# Deal: Myntra Shirt is available at ₹799.5 only!
