# %%
#task-1
import math
print(math.sqrt(225))
# Out:
# 15.0

# %%
#task-2
import os
folder_name="MyDownload"
os.mkdir(folder_name)
print(os.path.abspath(folder_name))
# Out:
# C:\Users\MAHEK\PycharmProjects\PythonProject\MyDownload

# %%
#task-3
from datetime import datetime
current_datetime = datetime.now()
formatte_datetime=current_datetime.strftime("%d-%m-%y %H:%M:%S")
print(formatte_datetime)
# Out:
# 31-08-26 00:06:55

# %%
#task-4
def add_song(playlist,song):
    playlist.append(song)

# %%
import playlist_utils

playlist = []

playlist_utils.add_song(playlist, "Kesariya")
playlist_utils.add_song(playlist, "Tum Hi Ho")
playlist_utils.add_song(playlist, "Apna Bana Le")

print(playlist)
# Out:
# ['Kesariya', 'Tum Hi Ho', 'Apna Bana Le']
